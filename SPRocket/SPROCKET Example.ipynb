# %%
# %cd '/content/drive/MyDrive/8th-semester/SAP/Project/sprocket'
# Out:
# /content/drive/MyDrive/8th-semester/SAP/Project/sprocket

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/SAP/Project/sprocket'
# Out:
# /content/drive/.shortcut-targets-by-id/1dCr4lZ4esQqtasZc1tICek9dGD5CCmi-/Project/sprocket

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import os
import sys

# %%
print(sys.path)
# sys.path.append('/content/drive/MyDrive/8th-semester/SAP/Project/sprocket')
sys.path.append('/content/drive/MyDrive/SAP/Project/sprocket')
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python39.zip', '/usr/lib/python3.9', '/usr/lib/python3.9/lib-dynload', '', '/usr/local/lib/python3.9/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.9/dist-packages/IPython/extensions', '/root/.ipython']
# ['/content', '/env/python', '/usr/lib/python39.zip', '/usr/lib/python3.9', '/usr/lib/python3.9/lib-dynload', '', '/usr/local/lib/python3.9/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.9/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/SAP/Project/sprocket']

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.8/276.8 kB 19.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.7/218.7 kB 20.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 18.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.1/140.1 kB 13.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
# %cd 'example'
# Out:
# /content/drive/.shortcut-targets-by-id/1dCr4lZ4esQqtasZc1tICek9dGD5CCmi-/Project/sprocket/example

# %%
# !python download_vcc2016data.py

# %%
# !pip install numpy --upgrade --ignore-installed
# !python initialize.py -1 SF1 TF1 16000
# Out:
# 1.24.2
# ### 1. create initial list files ###
# Generate /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/list/SF1_train.list
# Generate /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/list/TF1_train.list
# Generate /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/list/SF1_eval.list
# Generate /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/list/TF1_eval.list
# # Please modify train and eval list files, if you want. #

# %%
# !python initialize.py -2 SF1 TF1 16000
# Out:
# 1.24.2
# ### 2. create configure files ###
# Generate /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/conf/speaker/SF1.yml
# Generate /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/conf/speaker/TF1.yml
# Generate /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/conf/pair/SF1-TF1.yml

# %%
# !python initialize.py -3 SF1 TF1 16000
# Out:
# 1.24.2
# ### 3. create figures to define parameters ###
# Extract: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100001.wav
# Extract: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100002.wav
# Extract: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100003.wav
# Extract: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100004.wav
# Extract: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100005.wav
# Extract: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100006.wav
# Extract: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100007.wav
# Extract: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100008.wav
# Extract: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100009.wav
# ...

# %%
# !python run_sprocket.py -1 -2 -3 -4 -5 SF1 TF1
# Out:
# 1.24.2
# ### 1. Extract acoustic features ###
# Extract acoustic features: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100001.wav
# Extract acoustic features: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100002.wav
# Extract acoustic features: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100003.wav
# Extract acoustic features: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100004.wav
# Extract acoustic features: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100005.wav
# Extract acoustic features: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100006.wav
# Extract acoustic features: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100007.wav
# Extract acoustic features: /content/drive/MyDrive/8th-semester/SAP/Project/sprocket/example/data/wav/SF1/100008.wav
# ...
